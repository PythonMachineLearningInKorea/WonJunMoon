# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pwd
# %cd ./drive/My Drive/Colab Notebooks/UniverseDacon/
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')
sample_submission = pd.read_csv('sample_submission.csv', index_col=0)
sample_submission.describe()
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# pwd: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-518686dd6fb4>", line 2, in <module>
#     get_ipython().magic('cd ./drive/My Drive/Colab Notebooks/UniverseDacon/')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magics/osm.py", line 288, in cd
#     oldcwd = py3compat.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ---------------------------------------------------------------------------

# %%
# TRAIN 데이터의 TYPE을 SAMPLE_SUBMISSION에 대응하는 가변수 형태로 변환시킵니다.
column_number = {}
for i, column in enumerate(sample_submission.columns):
    column_number[column] = i
    
def to_number(x, dic):
    return dic[x]

train['type_num'] = train['type'].apply(lambda x: to_number(x, column_number))

# %% [markdown]
# train 에서 type column 을 없애고 test 랑 합쳐서 .
#
# IQR 방법으로 Outlier 제거.
# 일단 주석처리.

# %%
y_train = train['type_num']
train_wo_type = train.drop(columns=['type','type_num','fiberID'], axis=1)
test = test.drop(columns=['fiberID'])
total = pd.concat([train_wo_type, test])
total.info()

# %%
# from collections import Counter
# def detect_outliers(df, n, features): 
#   outlier_indices = [] 
#   for col in features:
#     if col == 'type' or col == 'id':
#       continue; 
#     Q1 = np.percentile(df[col], 25) 
#     Q3 = np.percentile(df[col], 75) 
#     IQR = Q3 - Q1 

#     outlier_step =  IQR 
#     outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step)].index 
#     outlier_indices.extend(outlier_list_col) 

#   outlier_indices = Counter(outlier_indices) 
#   multiple_outliers = list(k for k, v in outlier_indices.items() if v > n) 
#   print()
#   return multiple_outliers 

# features = total.columns
# print(features)
# dup = detect_outliers(total, 2, features)

# print(len(dup))

# filter(lambda a: a < 199991, dup)
# print(len(dup))

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.preprocessing import minmax_scale
#Scaler = StandardScaler()
#Scaler = MinMaxScaler()
Scaler = RobustScaler()

total[['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i','fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i','petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i','modelMag_z']] = Scaler.fit_transform(total[['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i','psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i','fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i','petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i','modelMag_z']])
total.describe()
X_train = total.iloc[:199991]
test = total.iloc[199991:]
X_train.describe()
# Out:
#                  id      psfMag_u  ...     modelMag_i     modelMag_z
# count  199991.00000  1.999910e+05  ...  199991.000000  199991.000000
# mean    99995.00000 -1.101418e+01  ...      -0.317283      -0.292707
# std     57732.57318  4.736054e+03  ...      43.853669      42.936817
# min         0.00000 -2.117774e+06  ...  -13033.426412   -8372.746487
# 25%     49997.50000 -4.856811e-01  ...      -0.556210      -0.447999
# 50%     99995.00000  3.220121e-04  ...       0.000081       0.000117
# 75%    149992.50000  5.143601e-01  ...       0.443718       0.552081
# max    199990.00000  7.478071e+03  ...    1351.832486    2377.503900
#
# [8 rows x 21 columns]

# %%
test.describe()
# Out:
#                   id      psfMag_u  ...    modelMag_i    modelMag_z
# count   10009.000000  10009.000000  ...  10009.000000  10009.000000
# mean   204995.000000      0.046595  ...     -0.039849      0.057952
# std      2889.493756      0.842075  ...      0.600664      0.599828
# min    199991.000000    -11.212789  ...     -1.900922     -1.832304
# 25%    202493.000000     -0.484511  ...     -0.558136     -0.444816
# 50%    204995.000000     -0.006439  ...     -0.002112     -0.001525
# 75%    207497.000000      0.514507  ...      0.444323      0.553477
# max    209999.000000      6.703486  ...      2.617526      2.043127
#
# [8 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, \
                                                  test_size=0.2, random_state=0)

# %%
# %%time
from xgboost import XGBClassifier

XGB_clf = XGBClassifier(max_depth = 7,n_esetimators=1500, n_jobs=-1, random_state=0)
print(XGB.get_params())
XGB_clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)])
# Out:
# [0]	validation_0-merror:0.133107	validation_1-merror:0.157004
# [1]	validation_0-merror:0.125494	validation_1-merror:0.150554
# [2]	validation_0-merror:0.122025	validation_1-merror:0.148079
# [3]	validation_0-merror:0.119106	validation_1-merror:0.146329
# [4]	validation_0-merror:0.116937	validation_1-merror:0.145279
# [5]	validation_0-merror:0.115162	validation_1-merror:0.144854
# [6]	validation_0-merror:0.113549	validation_1-merror:0.144429
# [7]	validation_0-merror:0.112012	validation_1-merror:0.143604
# [8]	validation_0-merror:0.110481	validation_1-merror:0.143429
# [9]	validation_0-merror:0.10928	validation_1-merror:0.142804
# [10]	validation_0-merror:0.108105	validation_1-merror:0.142229
# [11]	validation_0-merror:0.106905	validation_1-merror:0.142004
# [12]	validation_0-merror:0.105699	validation_1-merror:0.141954
# [13]	validation_0-merror:0.104724	validation_1-merror:0.141604
# [14]	validation_0-merror:0.103599	validation_1-merror:0.140854
# [15]	validation_0-merror:0.102724	validation_1-merror:0.140529
# [16]	validation_0-merror:0.101774	validation_1-merror:0.140304
# [17]	validation_0-merror:0.100999	validation_1-merror:0.140253
# [18]	validation_0-merror:0.100186	validation_1-merror:0.140379
# [19]	validation_0-merror:0.09918	validation_1-merror:0.140078
# [20]	validation_0-merror:0.098367	validation_1-merror:0.139603
# [21]	validation_0-merror:0.097474	validation_1-merror:0.139503
# [22]	validation_0-merror:0.09663	validation_1-merror:0.138853
# [23]	validation_0-merror:0.095867	validation_1-merror:0.138778
# [24]	validation_0-merror:0.094992	validation_1-merror:0.138503
# [25]	validation_0-merror:0.094217	validation_1-merror:0.138228
# [26]	validation_0-merror:0.093436	validation_1-merror:0.138203
# [27]	validation_0-merror:0.092917	validation_1-merror:0.137928
# [28]	validation_0-merror:0.092167	validation_1-merror:0.137878
# [29]	validation_0-merror:0.091505	validation_1-merror:0.137728
# [30]	validation_0-merror:0.090805	validation_1-merror:0.137853
# [31]	validation_0-merror:0.090017	validation_1-merror:0.137678
# [32]	validation_0-merror:0.089448	validation_1-merror:0.137578
# [33]	validation_0-merror:0.088573	validation_1-merror:0.137528
# [34]	validation_0-merror:0.087798	validation_1-merror:0.137303
# [35]	validation_0-merror:0.087142	validation_1-merror:0.137028
# [36]	validation_0-merror:0.086604	validation_1-merror:0.136853
# [37]	validation_0-merror:0.086148	validation_1-merror:0.136528
# [38]	validation_0-merror:0.085354	validation_1-merror:0.136503
# [39]	validation_0-merror:0.08476	validation_1-merror:0.136403
# [40]	validation_0-merror:0.084185	validation_1-merror:0.136128
# [41]	validation_0-merror:0.083842	validation_1-merror:0.136053
# [42]	validation_0-merror:0.083254	validation_1-merror:0.135703
# [43]	validation_0-merror:0.08271	validation_1-merror:0.135653
# [44]	validation_0-merror:0.082235	validation_1-merror:0.135703
# [45]	validation_0-merror:0.08166	validation_1-merror:0.135553
# [46]	validation_0-merror:0.081135	validation_1-merror:0.135678
# [47]	validation_0-merror:0.080817	validation_1-merror:0.135403
# [48]	validation_0-merror:0.080398	validation_1-merror:0.135203
# [49]	validation_0-merror:0.07971	validation_1-merror:0.135003
# [50]	validation_0-merror:0.079298	validation_1-merror:0.135203
# [51]	validation_0-merror:0.078748	validation_1-merror:0.134903
# [52]	validation_0-merror:0.078223	validation_1-merror:0.134853
# [53]	validation_0-merror:0.077735	validation_1-merror:0.134803
# [54]	validation_0-merror:0.077416	validation_1-merror:0.134753
# [55]	validation_0-merror:0.076991	validation_1-merror:0.134828
# [56]	validation_0-merror:0.076591	validation_1-merror:0.134853
# [57]	validation_0-merror:0.076229	validation_1-merror:0.134753
# [58]	validation_0-merror:0.075785	validation_1-merror:0.134928
# [59]	validation_0-merror:0.075329	validation_1-merror:0.134628
# [60]	validation_0-merror:0.074972	validation_1-merror:0.134453
# [61]	validation_0-merror:0.074566	validation_1-merror:0.134603
# [62]	validation_0-merror:0.074141	validation_1-merror:0.134403
# [63]	validation_0-merror:0.073779	validation_1-merror:0.134453
# [64]	validation_0-merror:0.073279	validation_1-merror:0.134153
# [65]	validation_0-merror:0.07291	validation_1-merror:0.134278
# [66]	validation_0-merror:0.072472	validation_1-merror:0.134228
# [67]	validation_0-merror:0.072129	validation_1-merror:0.134328
# [68]	validation_0-merror:0.071772	validation_1-merror:0.134253
# [69]	validation_0-merror:0.071435	validation_1-merror:0.134203
# [70]	validation_0-merror:0.071041	validation_1-merror:0.134103
# [71]	validation_0-merror:0.07076	validation_1-merror:0.133928
# [72]	validation_0-merror:0.070404	validation_1-merror:0.134003
# [73]	validation_0-merror:0.069991	validation_1-merror:0.133728
# [74]	validation_0-merror:0.069703	validation_1-merror:0.133878
# [75]	validation_0-merror:0.069385	validation_1-merror:0.134003
# [76]	validation_0-merror:0.06896	validation_1-merror:0.133953
# [77]	validation_0-merror:0.068672	validation_1-merror:0.133803
# [78]	validation_0-merror:0.068328	validation_1-merror:0.133603
# [79]	validation_0-merror:0.067966	validation_1-merror:0.133603
# [80]	validation_0-merror:0.067547	validation_1-merror:0.133828
# [81]	validation_0-merror:0.067197	validation_1-merror:0.133978
# [82]	validation_0-merror:0.066816	validation_1-merror:0.133903
# [83]	validation_0-merror:0.066528	validation_1-merror:0.133853
# [84]	validation_0-merror:0.066078	validation_1-merror:0.133903
# [85]	validation_0-merror:0.065603	validation_1-merror:0.133903
# [86]	validation_0-merror:0.065278	validation_1-merror:0.133778
# [87]	validation_0-merror:0.064978	validation_1-merror:0.133628
# [88]	validation_0-merror:0.064459	validation_1-merror:0.133403
# [89]	validation_0-merror:0.063953	validation_1-merror:0.133503
# [90]	validation_0-merror:0.063653	validation_1-merror:0.133253
# [91]	validation_0-merror:0.063166	validation_1-merror:0.133353
# [92]	validation_0-merror:0.062916	validation_1-merror:0.133303
# [93]	validation_0-merror:0.062509	validation_1-merror:0.133328
# [94]	validation_0-merror:0.062228	validation_1-merror:0.133253
# [95]	validation_0-merror:0.061853	validation_1-merror:0.133453
# [96]	validation_0-merror:0.061572	validation_1-merror:0.133528
# [97]	validation_0-merror:0.061247	validation_1-merror:0.133353
# [98]	validation_0-merror:0.060928	validation_1-merror:0.133528
# [99]	validation_0-merror:0.060616	validation_1-merror:0.133478
# CPU times: user 33min 44s, sys: 1.74 s, total: 33min 46s
# Wall time: 17min 6s

# %%
XGB_pred = XGB_clf.predict_proba(test)
submission = pd.DataFrame(data=XGB_pred, columns=sample_submission.columns, index=sample_submission.index)
submission.to_csv('XGBClassifier1.csv', index=True)
submission.describe()

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10009 entries, 199991 to 209999
# Data columns (total 19 columns):
# STAR_WHITE_DWARF       10009 non-null float64
# STAR_CATY_VAR          10009 non-null float64
# STAR_BROWN_DWARF       10009 non-null float64
# SERENDIPITY_RED        10009 non-null float64
# REDDEN_STD             10009 non-null float64
# STAR_BHB               10009 non-null float64
# GALAXY                 10009 non-null float64
# SERENDIPITY_DISTANT    10009 non-null float64
# QSO                    10009 non-null float64
# SKY                    10009 non-null float64
# STAR_RED_DWARF         10009 non-null float64
# ROSAT_D                10009 non-null float64
# STAR_PN                10009 non-null float64
# SERENDIPITY_FIRST      10009 non-null float64
# STAR_CARBON            10009 non-null float64
# SPECTROPHOTO_STD       10009 non-null float64
# STAR_SUB_DWARF         10009 non-null float64
# SERENDIPITY_MANUAL     10009 non-null float64
# SERENDIPITY_BLUE       10009 non-null float64
# dtypes: float64(19)
# memory usage: 1.5 MB

# %%
pd.DataFrame(XGB_pred).info()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-595f15d4a9b0>", line 1, in <module>
#     pd.DataFrame(XGB_pred).info()
# NameError: name 'XGB_pred' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/usr/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 107] Transport endpoint is not connected
# ---------------------------------------------------------------------------
